# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("C:/Users/KARUNA/Desktop/ProdigyInfo Internship/train.csv")
test_df = pd.read_csv("C:/Users/KARUNA/Desktop/ProdigyInfo Internship/test.csv")

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train_df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(train_df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.Cabin = train_df.Cabin.fillna("0")
print(train_df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
train_df.Age = train_df.Age.fillna("0")
print(train_df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
print(train_df.shape)
print("\n")
print(train_df.dtypes)
# Out:
# (891, 12)
#
#
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age             object
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_df.info()
print('_'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=train_df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=train_df,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=train_df,palette='magma')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='SibSp',data=train_df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
train_df['Fare'].hist(color='red',bins=40,figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Pclass',y='Age',data=test_df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
train_df.drop('Cabin',axis=1,inplace=True)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#converting categorical features into dummy variables
pd.get_dummies(train_df['Embarked'],drop_first=True).head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
sex=pd.get_dummies(train_df['Sex'],drop_first=True)
embark=pd.get_dummies(train_df['Embarked'],drop_first=True)

# %%
train_df.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True)

# %%
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass      Age  SibSp  Parch     Fare
# 0            1         0       3     22.0      1      0   7.2500
# 1            2         1       1     38.0      1      0  71.2833
# 2            3         1       3     26.0      0      0   7.9250
# 3            4         1       1     35.0      1      0  53.1000
# 4            5         0       3     35.0      0      0   8.0500
# 5            6         0       3  unknown      0      0   8.4583
# 6            7         0       1     54.0      0      0  51.8625
# 7            8         0       3      2.0      3      1  21.0750
# 8            9         1       3     27.0      0      2  11.1333
# 9           10         1       2     14.0      1      0  30.0708

# %%
train_df = pd.concat([train_df,sex,embark],axis=1)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0
# 2            3         1       3  26.0      0      0   7.9250     0  0  1
# 3            4         1       1  35.0      1      0  53.1000     0  0  1
# 4            5         0       3  35.0      0      0   8.0500     1  0  1

# %% [markdown]
# ## Logistic Regression Model

# %%
#Train test split
train_df.drop(['Survived'],axis=1).head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1       3  22.0      1      0   7.2500     1  0  1
# 1            2       1  38.0      1      0  71.2833     0  0  0
# 2            3       3  26.0      0      0   7.9250     0  0  1
# 3            4       1  35.0      1      0  53.1000     0  0  1
# 4            5       3  35.0      0      0   8.0500     1  0  1

# %%
train_df['Survived'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df.drop('Survived',axis=1),
                                                    train_df['Survived'],test_size=0.30,random_state=101)

# %%
pd.crosstab([train_df.Survived],train_df.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_0b138_row0_col0, #T_0b138_row1_col1, #T_0b138_row1_col2, #T_0b138_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_0b138_row0_col1 {
#   background-color: #e5f266;
#   color: #000000;
# }
# #T_0b138_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_0b138_row0_col3 {
#   background-color: #9fcf66;
#   color: #000000;
# }
# #T_0b138_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_0b138_row2_col0, #T_0b138_row2_col1, #T_0b138_row2_col2, #T_0b138_row2_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b138">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_0b138_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_0b138_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_0b138_level0_col2" class="col_heading level0 col2" >3</th>
# ...

# %%
sns.factorplot('Pclass', 'Survived', hue='Age', data=train_df)
plt.show()

# %%
pd.crosstab([train_df.SibSp],train_df.Survived).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_ca658_row0_col0, #T_ca658_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ca658_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_ca658_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_ca658_row2_col0, #T_ca658_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_ca658_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_ca658_row3_col0, #T_ca658_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_ca658_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_ca658_row5_col0, #T_ca658_row5_col1, #T_ca658_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ca658_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_ca658">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived', data=train_df,ax=ax[0])
ax[0].set_title('SipSp vs Survived in BarPlot')
plt.close(2)
plt.show()
# Out:
# C:\Users\KARUNA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(train_df.SibSp,train_df.Pclass).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_7ff93_row0_col0, #T_7ff93_row0_col1, #T_7ff93_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_7ff93_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_7ff93_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_7ff93_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_7ff93_row2_col0, #T_7ff93_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_7ff93_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_7ff93_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_7ff93_row3_col0, #T_7ff93_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_7ff93_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_7ff93_row4_col0, #T_7ff93_row4_col1, #T_7ff93_row5_col0, #T_7ff93_row5_col1, #T_7ff93_row5_col2, #T_7ff93_row6_col0, #T_7ff93_row6_col1 {
#   background-color: #ffff66;
# ...
